# %%
import keras
import os, sys
import numpy as np
import pandas as pd
import tensorflow as tf
import keras.backend as K
from google.colab import drive
from sklearn.metrics import mean_squared_error
from keras.models import Model
from tensorflow.keras import regularizers
from keras.layers import Flatten, Dense, Input, Embedding, Dot
from keras.layers import GlobalAveragePooling1D, MaxPooling1D, Dropout, BatchNormalization
from keras.optimizers import Adam

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load data
movie = [i.strip().split("::") for i in open("/content/drive/My Drive/MovieLens10M/movies.dat").readlines()]
movie = pd.DataFrame(movie)
movie = movie.rename(columns={0: "movieId", 1: "title", 2: "genres"})
rating = [i.strip().split("::") for i in open("/content/drive/My Drive/MovieLens10M/ratings.dat").readlines()]
rating = pd.DataFrame(rating)
rating = rating.rename(columns={0: "userId", 1: "movieId", 2: "rating", 3: "timestamp"})
movie = movie.loc[:,["movieId","genres"]]
rating = rating.loc[:,["userId","movieId","rating","timestamp"]]
data = pd.merge(rating, movie)
data['rating'] = pd.to_numeric(data['rating'])
data['timestamp'] = pd.to_numeric(data['timestamp'])

# %%
# preprocessing
n_movies = len(data['movieId'].unique())
n_users = len(data['userId'].unique())
genres_split = data.genres.str.split('|').tolist()
genres_unique = set()
for movie_genres in genres_split:
    for genre in movie_genres:
        genres_unique.add(genre)
genres2idx = {o:i+1 for i,o in enumerate(genres_unique)}
genres_split = [[genres2idx[x] for x in movie_genres] for movie_genres in genres_split]
padded_genres = tf.keras.preprocessing.sequence.pad_sequences(
    genres_split, padding="post"
)

users = data.userId.unique()
movies = data.movieId.unique()

userid2idx = {o:i for i,o in enumerate(users)}
movieid2idx = {o:i for i,o in enumerate(movies)}

data['userId'] = data['userId'].apply(lambda x: userid2idx[x])
data['movieId'] = data['movieId'].apply(lambda x: movieid2idx[x])

data = data.drop(columns=['genres'])
for i in range(len(padded_genres[0])):
    data['genre'+str(i)] = padded_genres[:,i]

min_timestamp = pd.DataFrame(data.loc[:,["movieId","timestamp"]].groupby(['movieId'], as_index=False).min())
min_timestamp = min_timestamp.sort_values(by=["movieId"], axis=0)
min_timestamp = min_timestamp.rename(columns={"timestamp": "min_timestamp"})
data = pd.merge(data, min_timestamp)
data['timestamp'] = data['timestamp'] - data['min_timestamp']
data['timestamp'] = data['timestamp'] / (60 * 60 * 24 * 365)
data = data.drop(columns=['min_timestamp'])
data['day'] = data['timestamp'] * 365 / (7 * 2)
data['day'] = data['day'].apply(lambda x: int(x))
days = data.day.unique()
n_days = len(days)
day2idx = {o:i for i,o in enumerate(days)}
data['day'] = data['day'].apply(lambda x: day2idx[x])
print(n_movies, n_users, len(rating), n_days)
# Out:
# 10677 69878 10000054 365

# %%
# split train and test data
split = np.random.rand(len(data)) < 0.9
train = data[split]
valid = data[~split]
data.head(10)
# Out:
#    userId  movieId  rating  timestamp  ...  genre5  genre6  genre7  day
# 0       0        0     5.0   0.347135  ...       0       0       0    0
# 1       1        0     3.0   4.638027  ...       0       0       0    1
# 2       2        0     2.5   9.015238  ...       0       0       0    2
# 3       3        0     3.0   3.659976  ...       0       0       0    3
# 4       4        0     4.5   8.702935  ...       0       0       0    4
# 5       5        0     3.0   0.519782  ...       0       0       0    5
# 6       6        0     3.0   0.520016  ...       0       0       0    5
# 7       7        0     3.0   0.347532  ...       0       0       0    0
# 8       8        0     1.0   4.052296  ...       0       0       0    6
# 9       9        0     3.0   3.736893  ...       0       0       0    7
#
# [10 rows x 13 columns]

# %%
# generate model
embedding_l2 = 1e-6 * 1                                  # regularization
dense_l2 = 1e-3 * 1                                      # regularization
keras.backend.clear_session()

user_input = Input(shape=(1,), name='user_input', dtype='int64')
movie_input = Input(shape=(1,), name='movie_input', dtype='int64')
genres_input = Input(shape=(len(padded_genres[0]),), name='genres_input', dtype='int64') # input = (10, 1)
day_input = Input(shape=(1,), name='day_input', dtype='int64')
time_input = Input(shape=(1,), name='time_input', dtype='float32')
time_root = tf.math.sqrt(time_input + 1.0)
time_square = tf.math.square(time_input)
time_vector = tf.concat([time_input, time_root, time_square], 1)

def create_model(n_user_embedding):
    n_movie_embedding = int(n_user_embedding * 0.75)
    n_genres_embedding = int(n_user_embedding * 0.25)

    user_embedding = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector = Flatten()(user_embedding)
    movie_embedding = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector = Flatten()(movie_embedding)
    genres_embedding = Embedding(len(genres_unique)+1, n_genres_embedding, mask_zero=True, embeddings_regularizer=regularizers.l2(embedding_l2/(len(genres_unique)+1)))(genres_input)
    genres_average_embedding = GlobalAveragePooling1D()(genres_embedding)
    genres_vector = Flatten()(genres_average_embedding)
    day_embedding = Embedding(n_days, int(n_user_embedding/8), embeddings_regularizer=regularizers.l2(embedding_l2))(day_input)
    day_vector = Flatten()(day_embedding)

    concat_layer = tf.concat([user_vector, movie_vector, genres_vector, time_vector, day_vector], 1)
    mlp_layer = Dense(int(n_user_embedding/2), activation='relu', kernel_regularizer=regularizers.l2(dense_l2))(concat_layer)

    user_embedding2 = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector2 = Flatten()(user_embedding2)
    movie_embedding2 = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector2 = Flatten()(movie_embedding2)
    genres_embedding2 = Embedding(len(genres_unique)+1, n_genres_embedding, mask_zero=True, embeddings_regularizer=regularizers.l2(embedding_l2/(len(genres_unique)+1)))(genres_input)
    genres_average_embedding2 = GlobalAveragePooling1D()(genres_embedding2)
    genres_vector2 = Flatten()(genres_average_embedding2)
    matrix_factorization = Dot(axes=1)([user_vector2, tf.concat([movie_vector2, genres_vector2], 1)])

    user_embedding3 = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector3 = Flatten()(user_embedding3)
    movie_embedding3 = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector3 = Flatten()(movie_embedding3)
    genres_embedding3 = Embedding(len(genres_unique)+1, n_genres_embedding, mask_zero=True, embeddings_regularizer=regularizers.l2(embedding_l2/(len(genres_unique)+1)))(genres_input)
    genres_average_embedding3 = GlobalAveragePooling1D()(genres_embedding3)
    genres_vector3 = Flatten()(genres_average_embedding3)
    diff = tf.math.subtract(user_vector3, tf.concat([movie_vector3, genres_vector3], 1))
    W = tf.Variable(tf.random.normal(shape=[n_user_embedding, 1], stddev=0.1))
    diff = tf.linalg.matmul(diff, W)

    output_layer = tf.concat([matrix_factorization, mlp_layer, diff], 1)
    return output_layer

output_layer = tf.concat([create_model(8*8), create_model(8*7), create_model(8*6), create_model(8*5), create_model(8*4), create_model(8*3), create_model(8*2), create_model(8*1)], 1)
output = Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(dense_l2))(output_layer)
output = output*5.5

model = Model([user_input, movie_input, time_input, genres_input, day_input], output)
model.summary()
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(64, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_1), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(56, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_2), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(48, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_3), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(40, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_4), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(32, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_5), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(24, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_6), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(16, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_7), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(8, 1) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# genres_input (InputLayer)       [(None, 8)]          0
# __________________________________________________________________________________________________
# movie_input (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# time_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 8, 16)        336         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 8, 14)        294         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_29 (Embedding)        (None, 8, 12)        252         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 8, 10)        210         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_49 (Embedding)        (None, 8, 8)         168         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_59 (Embedding)        (None, 8, 6)         126         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_69 (Embedding)        (None, 8, 4)         84          genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_79 (Embedding)        (None, 8, 2)         42          genres_input[0][0]
# __________________________________________________________________________________________________
# user_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 8, 16)        336         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 8, 16)        336         genres_input[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 1)            0           time_input[0][0]
# __________________________________________________________________________________________________
# day_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 16)           0           embedding_9[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 8, 14)        294         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 8, 14)        294         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 1, 42)        448434      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 14)           0           embedding_19[0][0]
# __________________________________________________________________________________________________
# embedding_26 (Embedding)        (None, 8, 12)        252         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 8, 12)        252         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_28 (Embedding)        (None, 1, 36)        384372      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_8 (Glo (None, 12)           0           embedding_29[0][0]
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 8, 10)        210         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_32 (Embedding)        (None, 8, 10)        210         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 1, 30)        320310      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_11 (Gl (None, 10)           0           embedding_39[0][0]
# __________________________________________________________________________________________________
# embedding_46 (Embedding)        (None, 8, 8)         168         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_42 (Embedding)        (None, 8, 8)         168         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_48 (Embedding)        (None, 1, 24)        256248      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_14 (Gl (None, 8)            0           embedding_49[0][0]
# __________________________________________________________________________________________________
# embedding_56 (Embedding)        (None, 8, 6)         126         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_52 (Embedding)        (None, 8, 6)         126         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_58 (Embedding)        (None, 1, 18)        192186      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_17 (Gl (None, 6)            0           embedding_59[0][0]
# __________________________________________________________________________________________________
# embedding_66 (Embedding)        (None, 8, 4)         84          genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_62 (Embedding)        (None, 8, 4)         84          genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_68 (Embedding)        (None, 1, 12)        128124      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_20 (Gl (None, 4)            0           embedding_69[0][0]
# __________________________________________________________________________________________________
# embedding_76 (Embedding)        (None, 8, 2)         42          genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_72 (Embedding)        (None, 8, 2)         42          genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_78 (Embedding)        (None, 1, 6)         64062       movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_23 (Gl (None, 2)            0           embedding_79[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 16)           0           embedding_6[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 16)           0           embedding_2[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt (TFOpLambda)       (None, 1)            0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 1)            0           time_input[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 8)         2920        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 48)           0           embedding_8[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 16)           0           global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 1, 42)        448434      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 14)           0           embedding_16[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 1, 56)        3913168     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 1, 42)        448434      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 14)           0           embedding_12[0][0]
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 1, 7)         2555        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 1, 56)        3913168     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 42)           0           embedding_18[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 14)           0           global_average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# embedding_25 (Embedding)        (None, 1, 36)        384372      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 12)           0           embedding_26[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 1, 36)        384372      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_6 (Glo (None, 12)           0           embedding_22[0][0]
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 1, 6)         2190        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_27 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 36)           0           embedding_28[0][0]
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 12)           0           global_average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# embedding_35 (Embedding)        (None, 1, 30)        320310      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_10 (Gl (None, 10)           0           embedding_36[0][0]
# __________________________________________________________________________________________________
# embedding_30 (Embedding)        (None, 1, 40)        2795120     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_31 (Embedding)        (None, 1, 30)        320310      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 10)           0           embedding_32[0][0]
# __________________________________________________________________________________________________
# embedding_33 (Embedding)        (None, 1, 5)         1825        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 1, 40)        2795120     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_38 (Flatten)            (None, 30)           0           embedding_38[0][0]
# __________________________________________________________________________________________________
# flatten_39 (Flatten)            (None, 10)           0           global_average_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# embedding_45 (Embedding)        (None, 1, 24)        256248      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_13 (Gl (None, 8)            0           embedding_46[0][0]
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 1, 24)        256248      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_12 (Gl (None, 8)            0           embedding_42[0][0]
# __________________________________________________________________________________________________
# embedding_43 (Embedding)        (None, 1, 4)         1460        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_47 (Embedding)        (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_48 (Flatten)            (None, 24)           0           embedding_48[0][0]
# __________________________________________________________________________________________________
# flatten_49 (Flatten)            (None, 8)            0           global_average_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# embedding_55 (Embedding)        (None, 1, 18)        192186      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_16 (Gl (None, 6)            0           embedding_56[0][0]
# __________________________________________________________________________________________________
# embedding_50 (Embedding)        (None, 1, 24)        1677072     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_51 (Embedding)        (None, 1, 18)        192186      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_15 (Gl (None, 6)            0           embedding_52[0][0]
# __________________________________________________________________________________________________
# embedding_53 (Embedding)        (None, 1, 3)         1095        day_input[0][0]
# __________________________________________________________________________________________________
# embedding_57 (Embedding)        (None, 1, 24)        1677072     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_58 (Flatten)            (None, 18)           0           embedding_58[0][0]
# __________________________________________________________________________________________________
# flatten_59 (Flatten)            (None, 6)            0           global_average_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# embedding_65 (Embedding)        (None, 1, 12)        128124      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_19 (Gl (None, 4)            0           embedding_66[0][0]
# __________________________________________________________________________________________________
# embedding_60 (Embedding)        (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_61 (Embedding)        (None, 1, 12)        128124      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_18 (Gl (None, 4)            0           embedding_62[0][0]
# __________________________________________________________________________________________________
# embedding_63 (Embedding)        (None, 1, 2)         730         day_input[0][0]
# __________________________________________________________________________________________________
# embedding_67 (Embedding)        (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_68 (Flatten)            (None, 12)           0           embedding_68[0][0]
# __________________________________________________________________________________________________
# flatten_69 (Flatten)            (None, 4)            0           global_average_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# embedding_75 (Embedding)        (None, 1, 6)         64062       movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_22 (Gl (None, 2)            0           embedding_76[0][0]
# __________________________________________________________________________________________________
# embedding_70 (Embedding)        (None, 1, 8)         559024      user_input[0][0]
# __________________________________________________________________________________________________
# embedding_71 (Embedding)        (None, 1, 6)         64062       movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_21 (Gl (None, 2)            0           embedding_72[0][0]
# __________________________________________________________________________________________________
# embedding_73 (Embedding)        (None, 1, 1)         365         day_input[0][0]
# __________________________________________________________________________________________________
# embedding_77 (Embedding)        (None, 1, 8)         559024      user_input[0][0]
# __________________________________________________________________________________________________
# flatten_78 (Flatten)            (None, 6)            0           embedding_78[0][0]
# __________________________________________________________________________________________________
# flatten_79 (Flatten)            (None, 2)            0           global_average_pooling1d_23[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 48)           0           embedding_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 16)           0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 48)           0           embedding_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 16)           0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 3)            0           time_input[0][0]
#                                                                  tf.math.sqrt[0][0]
#                                                                  tf.math.square[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 8)            0           embedding_3[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 64)           0           embedding_7[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 64)           0           flatten_8[0][0]
#                                                                  flatten_9[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 1, 56)        3913168     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 42)           0           embedding_15[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 14)           0           global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 56)           0           embedding_10[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 42)           0           embedding_11[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 14)           0           global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 7)            0           embedding_13[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 56)           0           embedding_17[0][0]
# __________________________________________________________________________________________________
# tf.concat_7 (TFOpLambda)        (None, 56)           0           flatten_18[0][0]
#                                                                  flatten_19[0][0]
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 36)           0           embedding_25[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 12)           0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 48)           0           embedding_20[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 36)           0           embedding_21[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 12)           0           global_average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 6)            0           embedding_23[0][0]
# __________________________________________________________________________________________________
# flatten_27 (Flatten)            (None, 48)           0           embedding_27[0][0]
# __________________________________________________________________________________________________
# tf.concat_11 (TFOpLambda)       (None, 48)           0           flatten_28[0][0]
#                                                                  flatten_29[0][0]
# __________________________________________________________________________________________________
# embedding_34 (Embedding)        (None, 1, 40)        2795120     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_35 (Flatten)            (None, 30)           0           embedding_35[0][0]
# __________________________________________________________________________________________________
# flatten_36 (Flatten)            (None, 10)           0           global_average_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 40)           0           embedding_30[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 30)           0           embedding_31[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 10)           0           global_average_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_33 (Flatten)            (None, 5)            0           embedding_33[0][0]
# __________________________________________________________________________________________________
# flatten_37 (Flatten)            (None, 40)           0           embedding_37[0][0]
# __________________________________________________________________________________________________
# tf.concat_15 (TFOpLambda)       (None, 40)           0           flatten_38[0][0]
#                                                                  flatten_39[0][0]
# __________________________________________________________________________________________________
# embedding_44 (Embedding)        (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_45 (Flatten)            (None, 24)           0           embedding_45[0][0]
# __________________________________________________________________________________________________
# flatten_46 (Flatten)            (None, 8)            0           global_average_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_40 (Flatten)            (None, 32)           0           embedding_40[0][0]
# __________________________________________________________________________________________________
# flatten_41 (Flatten)            (None, 24)           0           embedding_41[0][0]
# __________________________________________________________________________________________________
# flatten_42 (Flatten)            (None, 8)            0           global_average_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_43 (Flatten)            (None, 4)            0           embedding_43[0][0]
# __________________________________________________________________________________________________
# flatten_47 (Flatten)            (None, 32)           0           embedding_47[0][0]
# __________________________________________________________________________________________________
# tf.concat_19 (TFOpLambda)       (None, 32)           0           flatten_48[0][0]
#                                                                  flatten_49[0][0]
# __________________________________________________________________________________________________
# embedding_54 (Embedding)        (None, 1, 24)        1677072     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_55 (Flatten)            (None, 18)           0           embedding_55[0][0]
# __________________________________________________________________________________________________
# flatten_56 (Flatten)            (None, 6)            0           global_average_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# flatten_50 (Flatten)            (None, 24)           0           embedding_50[0][0]
# __________________________________________________________________________________________________
# flatten_51 (Flatten)            (None, 18)           0           embedding_51[0][0]
# __________________________________________________________________________________________________
# flatten_52 (Flatten)            (None, 6)            0           global_average_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# flatten_53 (Flatten)            (None, 3)            0           embedding_53[0][0]
# __________________________________________________________________________________________________
# flatten_57 (Flatten)            (None, 24)           0           embedding_57[0][0]
# __________________________________________________________________________________________________
# tf.concat_23 (TFOpLambda)       (None, 24)           0           flatten_58[0][0]
#                                                                  flatten_59[0][0]
# __________________________________________________________________________________________________
# embedding_64 (Embedding)        (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# flatten_65 (Flatten)            (None, 12)           0           embedding_65[0][0]
# __________________________________________________________________________________________________
# flatten_66 (Flatten)            (None, 4)            0           global_average_pooling1d_19[0][0]
# __________________________________________________________________________________________________
# flatten_60 (Flatten)            (None, 16)           0           embedding_60[0][0]
# __________________________________________________________________________________________________
# flatten_61 (Flatten)            (None, 12)           0           embedding_61[0][0]
# __________________________________________________________________________________________________
# flatten_62 (Flatten)            (None, 4)            0           global_average_pooling1d_18[0][0]
# __________________________________________________________________________________________________
# flatten_63 (Flatten)            (None, 2)            0           embedding_63[0][0]
# __________________________________________________________________________________________________
# flatten_67 (Flatten)            (None, 16)           0           embedding_67[0][0]
# __________________________________________________________________________________________________
# tf.concat_27 (TFOpLambda)       (None, 16)           0           flatten_68[0][0]
#                                                                  flatten_69[0][0]
# __________________________________________________________________________________________________
# embedding_74 (Embedding)        (None, 1, 8)         559024      user_input[0][0]
# __________________________________________________________________________________________________
# flatten_75 (Flatten)            (None, 6)            0           embedding_75[0][0]
# __________________________________________________________________________________________________
# flatten_76 (Flatten)            (None, 2)            0           global_average_pooling1d_22[0][0]
# __________________________________________________________________________________________________
# flatten_70 (Flatten)            (None, 8)            0           embedding_70[0][0]
# __________________________________________________________________________________________________
# flatten_71 (Flatten)            (None, 6)            0           embedding_71[0][0]
# __________________________________________________________________________________________________
# flatten_72 (Flatten)            (None, 2)            0           global_average_pooling1d_21[0][0]
# __________________________________________________________________________________________________
# flatten_73 (Flatten)            (None, 1)            0           embedding_73[0][0]
# __________________________________________________________________________________________________
# flatten_77 (Flatten)            (None, 8)            0           embedding_77[0][0]
# __________________________________________________________________________________________________
# tf.concat_31 (TFOpLambda)       (None, 8)            0           flatten_78[0][0]
#                                                                  flatten_79[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           embedding_4[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 64)           0           flatten_5[0][0]
#                                                                  flatten_6[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 139)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 64)           0           flatten_7[0][0]
#                                                                  tf.concat_3[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 56)           0           embedding_14[0][0]
# __________________________________________________________________________________________________
# tf.concat_6 (TFOpLambda)        (None, 56)           0           flatten_15[0][0]
#                                                                  flatten_16[0][0]
# __________________________________________________________________________________________________
# tf.concat_5 (TFOpLambda)        (None, 122)          0           flatten_10[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 56)           0           flatten_17[0][0]
#                                                                  tf.concat_7[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 48)           0           embedding_24[0][0]
# __________________________________________________________________________________________________
# tf.concat_10 (TFOpLambda)       (None, 48)           0           flatten_25[0][0]
#                                                                  flatten_26[0][0]
# __________________________________________________________________________________________________
# tf.concat_9 (TFOpLambda)        (None, 105)          0           flatten_20[0][0]
#                                                                  flatten_21[0][0]
#                                                                  flatten_22[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_23[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 48)           0           flatten_27[0][0]
#                                                                  tf.concat_11[0][0]
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 40)           0           embedding_34[0][0]
# __________________________________________________________________________________________________
# tf.concat_14 (TFOpLambda)       (None, 40)           0           flatten_35[0][0]
#                                                                  flatten_36[0][0]
# __________________________________________________________________________________________________
# tf.concat_13 (TFOpLambda)       (None, 88)           0           flatten_30[0][0]
#                                                                  flatten_31[0][0]
#                                                                  flatten_32[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_33[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) (None, 40)           0           flatten_37[0][0]
#                                                                  tf.concat_15[0][0]
# __________________________________________________________________________________________________
# flatten_44 (Flatten)            (None, 32)           0           embedding_44[0][0]
# __________________________________________________________________________________________________
# tf.concat_18 (TFOpLambda)       (None, 32)           0           flatten_45[0][0]
#                                                                  flatten_46[0][0]
# __________________________________________________________________________________________________
# tf.concat_17 (TFOpLambda)       (None, 71)           0           flatten_40[0][0]
#                                                                  flatten_41[0][0]
#                                                                  flatten_42[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_43[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_4 (TFOpLambda) (None, 32)           0           flatten_47[0][0]
#                                                                  tf.concat_19[0][0]
# __________________________________________________________________________________________________
# flatten_54 (Flatten)            (None, 24)           0           embedding_54[0][0]
# __________________________________________________________________________________________________
# tf.concat_22 (TFOpLambda)       (None, 24)           0           flatten_55[0][0]
#                                                                  flatten_56[0][0]
# __________________________________________________________________________________________________
# tf.concat_21 (TFOpLambda)       (None, 54)           0           flatten_50[0][0]
#                                                                  flatten_51[0][0]
#                                                                  flatten_52[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_53[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_5 (TFOpLambda) (None, 24)           0           flatten_57[0][0]
#                                                                  tf.concat_23[0][0]
# __________________________________________________________________________________________________
# flatten_64 (Flatten)            (None, 16)           0           embedding_64[0][0]
# __________________________________________________________________________________________________
# tf.concat_26 (TFOpLambda)       (None, 16)           0           flatten_65[0][0]
#                                                                  flatten_66[0][0]
# __________________________________________________________________________________________________
# tf.concat_25 (TFOpLambda)       (None, 37)           0           flatten_60[0][0]
#                                                                  flatten_61[0][0]
#                                                                  flatten_62[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_63[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 16)           0           flatten_67[0][0]
#                                                                  tf.concat_27[0][0]
# __________________________________________________________________________________________________
# flatten_74 (Flatten)            (None, 8)            0           embedding_74[0][0]
# __________________________________________________________________________________________________
# tf.concat_30 (TFOpLambda)       (None, 8)            0           flatten_75[0][0]
#                                                                  flatten_76[0][0]
# __________________________________________________________________________________________________
# tf.concat_29 (TFOpLambda)       (None, 20)           0           flatten_70[0][0]
#                                                                  flatten_71[0][0]
#                                                                  flatten_72[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_73[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 8)            0           flatten_77[0][0]
#                                                                  tf.concat_31[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           flatten_4[0][0]
#                                                                  tf.concat_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           4480        tf.concat_1[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 1)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           flatten_14[0][0]
#                                                                  tf.concat_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 28)           3444        tf.concat_5[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_1 (TFOpLambda) (None, 1)            0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1)            0           flatten_24[0][0]
#                                                                  tf.concat_10[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 24)           2544        tf.concat_9[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_2 (TFOpLambda) (None, 1)            0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 1)            0           flatten_34[0][0]
#                                                                  tf.concat_14[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 20)           1780        tf.concat_13[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_3 (TFOpLambda) (None, 1)            0           tf.math.subtract_3[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1)            0           flatten_44[0][0]
#                                                                  tf.concat_18[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           1152        tf.concat_17[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_4 (TFOpLambda) (None, 1)            0           tf.math.subtract_4[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1)            0           flatten_54[0][0]
#                                                                  tf.concat_22[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 12)           660         tf.concat_21[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_5 (TFOpLambda) (None, 1)            0           tf.math.subtract_5[0][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 1)            0           flatten_64[0][0]
#                                                                  tf.concat_26[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 8)            304         tf.concat_25[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_6 (TFOpLambda) (None, 1)            0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 1)            0           flatten_74[0][0]
#                                                                  tf.concat_30[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            84          tf.concat_29[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_7 (TFOpLambda) (None, 1)            0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.concat_4 (TFOpLambda)        (None, 34)           0           dot[0][0]
#                                                                  dense[0][0]
#                                                                  tf.linalg.matmul[0][0]
# __________________________________________________________________________________________________
# tf.concat_8 (TFOpLambda)        (None, 30)           0           dot_1[0][0]
#                                                                  dense_1[0][0]
#                                                                  tf.linalg.matmul_1[0][0]
# __________________________________________________________________________________________________
# tf.concat_12 (TFOpLambda)       (None, 26)           0           dot_2[0][0]
#                                                                  dense_2[0][0]
#                                                                  tf.linalg.matmul_2[0][0]
# __________________________________________________________________________________________________
# tf.concat_16 (TFOpLambda)       (None, 22)           0           dot_3[0][0]
#                                                                  dense_3[0][0]
#                                                                  tf.linalg.matmul_3[0][0]
# __________________________________________________________________________________________________
# tf.concat_20 (TFOpLambda)       (None, 18)           0           dot_4[0][0]
#                                                                  dense_4[0][0]
#                                                                  tf.linalg.matmul_4[0][0]
# __________________________________________________________________________________________________
# tf.concat_24 (TFOpLambda)       (None, 14)           0           dot_5[0][0]
#                                                                  dense_5[0][0]
#                                                                  tf.linalg.matmul_5[0][0]
# __________________________________________________________________________________________________
# tf.concat_28 (TFOpLambda)       (None, 10)           0           dot_6[0][0]
#                                                                  dense_6[0][0]
#                                                                  tf.linalg.matmul_6[0][0]
# __________________________________________________________________________________________________
# tf.concat_32 (TFOpLambda)       (None, 6)            0           dot_7[0][0]
#                                                                  dense_7[0][0]
#                                                                  tf.linalg.matmul_7[0][0]
# __________________________________________________________________________________________________
# tf.concat_33 (TFOpLambda)       (None, 160)          0           tf.concat_4[0][0]
#                                                                  tf.concat_8[0][0]
#                                                                  tf.concat_12[0][0]
#                                                                  tf.concat_16[0][0]
#                                                                  tf.concat_20[0][0]
#                                                                  tf.concat_24[0][0]
#                                                                  tf.concat_28[0][0]
#                                                                  tf.concat_32[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            161         tf.concat_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 1)            0           dense_8[0][0]
# ==================================================================================================
# Total params: 67,325,573
# Trainable params: 67,325,573
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training
def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

model.compile(optimizer=Adam(), loss='mse', metrics=[rmse])
batch_size = 4096*8
epochs = 128

callback = tf.keras.callbacks.EarlyStopping(monitor='val_rmse', patience=1, restore_best_weights=True)
history = model.fit([train.userId, train.movieId, train.timestamp, train.iloc[:,4:12], train.day], train.rating,
                batch_size=batch_size, epochs=epochs, callbacks=[callback],
                validation_data = ([valid.userId, valid.movieId, valid.timestamp, valid.iloc[:,4:12], valid.day], valid.rating), verbose = 1)
# Out:
# Epoch 1/128
# 275/275 [==============================] - 409s 1s/step - loss: 1.1263 - rmse: 0.9608 - val_loss: 0.7796 - val_rmse: 0.8545
# Epoch 2/128
# 275/275 [==============================] - 385s 1s/step - loss: 0.7432 - rmse: 0.8336 - val_loss: 0.6969 - val_rmse: 0.8044
# Epoch 3/128
# 275/275 [==============================] - 379s 1s/step - loss: 0.6287 - rmse: 0.7578 - val_loss: 0.6750 - val_rmse: 0.7833
# Epoch 4/128
# 275/275 [==============================] - 373s 1s/step - loss: 0.5278 - rmse: 0.6792 - val_loss: 0.6873 - val_rmse: 0.7824
# Epoch 5/128
# 275/275 [==============================] - 374s 1s/step - loss: 0.4326 - rmse: 0.5945 - val_loss: 0.7188 - val_rmse: 0.7954

# %%
# check final RMSE
valid_pred = model.predict([valid.userId, valid.movieId, valid.timestamp, valid.iloc[:,4:12], valid.day], batch_size = batch_size)
valid_pred = [max(min(x, 5), 0.5) for x in valid_pred]
test_rmse = mean_squared_error(valid.rating, valid_pred, squared=False) # squared=False -> RMSE
print(test_rmse)
# Out:
# 0.7819186486327557
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
