# %%
import keras
import os, sys
import numpy as np
import pandas as pd
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
from google.colab import drive
from sklearn.metrics import mean_squared_error
from keras.models import Model
from tensorflow.keras import regularizers
from keras.layers import Flatten, Dense, Input, Embedding, Dot
from keras.layers import GlobalAveragePooling1D, MaxPooling1D, Dropout, BatchNormalization

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load data
movie = [i.strip().split("::") for i in open("/content/drive/My Drive/MovieLens10M/movies.dat").readlines()]
movie = pd.DataFrame(movie)
movie = movie.rename(columns={0: "movieId", 1: "title", 2: "genres"})
rating = [i.strip().split("::") for i in open("/content/drive/My Drive/MovieLens10M/ratings.dat").readlines()]
rating = pd.DataFrame(rating)
rating = rating.rename(columns={0: "userId", 1: "movieId", 2: "rating", 3: "timestamp"})
movie = movie.loc[:,["movieId","genres"]]
rating = rating.loc[:,["userId","movieId","rating","timestamp"]]
data = pd.merge(rating, movie)
data['rating'] = pd.to_numeric(data['rating'])
data['timestamp'] = pd.to_numeric(data['timestamp'])
print("MovieLens" + str(int(len(rating)/1000000)) + "M dataset loaded")
del(movie)
del(rating)
# Out:
# MovieLens10M dataset loaded

# %%
# preprocessing
n_movies = len(data['movieId'].unique())
n_users = len(data['userId'].unique())
genres_split = data.genres.str.split('|').tolist()
genres_unique = set()
for movie_genres in genres_split:
    for genre in movie_genres:
        genres_unique.add(genre)
genres2idx = {o:i+1 for i,o in enumerate(genres_unique)}
genres_split = [[genres2idx[x] for x in movie_genres] for movie_genres in genres_split]
padded_genres = tf.keras.preprocessing.sequence.pad_sequences(
    genres_split, padding="post"
)

users = data.userId.unique()
movies = data.movieId.unique()

userid2idx = {o:i for i,o in enumerate(users)}
movieid2idx = {o:i for i,o in enumerate(movies)}

data['userId'] = data['userId'].apply(lambda x: userid2idx[x])
data['movieId'] = data['movieId'].apply(lambda x: movieid2idx[x])
del(userid2idx)
del(movieid2idx)

n_genres = len(padded_genres[0])
data = data.drop(columns=['genres'])
for i in range(n_genres):
    data['genre'+str(i)] = padded_genres[:,i]
del(genres_split)
del(padded_genres)

min_timestamp = pd.DataFrame(data.loc[:,["movieId","timestamp"]].groupby(['movieId'], as_index=False).min())
min_timestamp = min_timestamp.sort_values(by=["movieId"], axis=0)
min_timestamp = min_timestamp.rename(columns={"timestamp": "min_timestamp"})
data = pd.merge(data, min_timestamp)
del(min_timestamp)
data['timestamp'] = data['timestamp'] - data['min_timestamp']
data['timestamp'] = data['timestamp'] / (60 * 60 * 24 * 365)
data = data.drop(columns=['min_timestamp'])
data['day'] = data['timestamp'] * 365 / (7 * 2)
data['day'] = data['day'].apply(lambda x: int(x))
days = data.day.unique()
n_days = len(days)
day2idx = {o:i for i,o in enumerate(days)}
data['day'] = data['day'].apply(lambda x: day2idx[x])
del(day2idx)
print(n_movies, n_users, n_days)
data.head(10)
# Out:
# 10677 69878 365
#    userId  movieId  rating  timestamp  ...  genre5  genre6  genre7  day
# 0       0        0     5.0   0.347135  ...       0       0       0    0
# 1       1        0     3.0   4.638027  ...       0       0       0    1
# 2       2        0     2.5   9.015238  ...       0       0       0    2
# 3       3        0     3.0   3.659976  ...       0       0       0    3
# 4       4        0     4.5   8.702935  ...       0       0       0    4
# 5       5        0     3.0   0.519782  ...       0       0       0    5
# 6       6        0     3.0   0.520016  ...       0       0       0    5
# 7       7        0     3.0   0.347532  ...       0       0       0    0
# 8       8        0     1.0   4.052296  ...       0       0       0    6
# 9       9        0     3.0   3.736893  ...       0       0       0    7
#
# [10 rows x 13 columns]

# %%
# split train and test data
data = data.sample(frac=1) # shuffle data
train = data[:int(len(data) * 0.9)]
valid = data[int(len(data) * 0.9):]
del(data)

# %%
# generate model
embedding_l2 = 1e-7 * 6                                  # regularization
dense_l2 = 1e-4 * 6                                      # regularization
keras.backend.clear_session()

user_input = Input(shape=(1,), name='user_input', dtype='int32')
movie_input = Input(shape=(1,), name='movie_input', dtype='int32')
genres_input = Input(shape=(n_genres,), name='genres_input', dtype='int32')
day_input = Input(shape=(1,), name='day_input', dtype='int32')
time_input = Input(shape=(1,), name='time_input', dtype='float32')
time_root = tf.math.sqrt(time_input + 1.0)
time_square = tf.math.square(time_input)
time_vector = tf.concat([time_input, time_root, time_square], 1)

def create_model(n_user_embedding):
    n_movie_embedding = n_user_embedding
    n_genres_embedding = int(n_user_embedding / 4)

    user_embedding = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector = Flatten()(user_embedding)
    movie_embedding = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector = Flatten()(movie_embedding)
    genres_embedding = Embedding(len(genres_unique)+1, n_genres_embedding, mask_zero=True, embeddings_regularizer=regularizers.l2(embedding_l2/n_genres))(genres_input)
    genres_average_embedding = GlobalAveragePooling1D()(genres_embedding)
    genres_vector = Flatten()(genres_average_embedding)
    day_embedding = Embedding(n_days, int(n_user_embedding/8), embeddings_regularizer=regularizers.l2(embedding_l2))(day_input)
    day_vector = Flatten()(day_embedding)

    concat_layer = tf.concat([user_vector, movie_vector, time_vector, genres_vector, day_vector], 1)
    mlp_output = Dense(int(n_user_embedding/2), activation='relu', kernel_regularizer=regularizers.l2(dense_l2))(concat_layer)


    user_embedding2 = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector2 = Flatten()(user_embedding2)
    movie_embedding2 = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector2 = Flatten()(movie_embedding2)
    MF = Dot(axes=1)([user_vector2, movie_vector2])


    user_embedding3 = Embedding(n_users, n_user_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(user_input)
    user_vector3 = Flatten()(user_embedding3)
    movie_embedding3 = Embedding(n_movies, n_movie_embedding, embeddings_regularizer=regularizers.l2(embedding_l2))(movie_input)
    movie_vector3 = Flatten()(movie_embedding3)
    diff = tf.reduce_sum(tf.multiply(user_vector3, movie_vector3), axis=1)
    diff = Flatten()(diff)

    output_layer = tf.concat([mlp_output, MF, diff], 1)
    return output_layer

output_layer = tf.concat([create_model(16*x) for x in range(1,9)], 1)
output = Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(dense_l2))(output_layer)
output = output*5.5

model = Model([user_input, movie_input, time_input, genres_input, day_input], output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# movie_input (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# time_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# genres_input (InputLayer)       [(None, 8)]          0
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 1)            0           time_input[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 8, 4)         84          genres_input[0][0]
# __________________________________________________________________________________________________
# day_input (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 1, 16)        170832      movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 8, 8)         168         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 1, 32)        341664      movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 8, 12)        252         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_26 (Embedding)        (None, 8, 16)        336         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_30 (Embedding)        (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_31 (Embedding)        (None, 1, 64)        683328      movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_34 (Embedding)        (None, 8, 20)        420         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 1, 80)        5590240     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 1, 80)        854160      movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_42 (Embedding)        (None, 8, 24)        504         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_46 (Embedding)        (None, 1, 96)        6708288     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_47 (Embedding)        (None, 1, 96)        1024992     movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_50 (Embedding)        (None, 8, 28)        588         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_54 (Embedding)        (None, 1, 112)       7826336     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_55 (Embedding)        (None, 1, 112)       1195824     movie_input[0][0]
# __________________________________________________________________________________________________
# embedding_58 (Embedding)        (None, 8, 32)        672         genres_input[0][0]
# __________________________________________________________________________________________________
# embedding_62 (Embedding)        (None, 1, 128)       8944384     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_63 (Embedding)        (None, 1, 128)       1366656     movie_input[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 16)        170832      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.sqrt (TFOpLambda)       (None, 1)            0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 1)            0           time_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 4)            0           embedding_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 2)         730         day_input[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 16)           0           embedding_6[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 16)           0           embedding_7[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 1, 32)        341664      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 8)            0           embedding_10[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 1, 4)         1460        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 32)           0           embedding_14[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 32)           0           embedding_15[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 12)           0           embedding_18[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 1, 6)         2190        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 48)           0           embedding_22[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 48)           0           embedding_23[0][0]
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_25 (Embedding)        (None, 1, 64)        683328      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 16)           0           embedding_26[0][0]
# __________________________________________________________________________________________________
# embedding_27 (Embedding)        (None, 1, 8)         2920        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_33 (Flatten)            (None, 64)           0           embedding_30[0][0]
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 64)           0           embedding_31[0][0]
# __________________________________________________________________________________________________
# embedding_32 (Embedding)        (None, 1, 80)        5590240     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_33 (Embedding)        (None, 1, 80)        854160      movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 20)           0           embedding_34[0][0]
# __________________________________________________________________________________________________
# embedding_35 (Embedding)        (None, 1, 10)        3650        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_42 (Flatten)            (None, 80)           0           embedding_38[0][0]
# __________________________________________________________________________________________________
# flatten_43 (Flatten)            (None, 80)           0           embedding_39[0][0]
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 1, 96)        6708288     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 1, 96)        1024992     movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 24)           0           embedding_42[0][0]
# __________________________________________________________________________________________________
# embedding_43 (Embedding)        (None, 1, 12)        4380        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_51 (Flatten)            (None, 96)           0           embedding_46[0][0]
# __________________________________________________________________________________________________
# flatten_52 (Flatten)            (None, 96)           0           embedding_47[0][0]
# __________________________________________________________________________________________________
# embedding_48 (Embedding)        (None, 1, 112)       7826336     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_49 (Embedding)        (None, 1, 112)       1195824     movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_6 (Glo (None, 28)           0           embedding_50[0][0]
# __________________________________________________________________________________________________
# embedding_51 (Embedding)        (None, 1, 14)        5110        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_60 (Flatten)            (None, 112)          0           embedding_54[0][0]
# __________________________________________________________________________________________________
# flatten_61 (Flatten)            (None, 112)          0           embedding_55[0][0]
# __________________________________________________________________________________________________
# embedding_56 (Embedding)        (None, 1, 128)       8944384     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_57 (Embedding)        (None, 1, 128)       1366656     movie_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 32)           0           embedding_58[0][0]
# __________________________________________________________________________________________________
# embedding_59 (Embedding)        (None, 1, 16)        5840        day_input[0][0]
# __________________________________________________________________________________________________
# flatten_69 (Flatten)            (None, 128)          0           embedding_62[0][0]
# __________________________________________________________________________________________________
# flatten_70 (Flatten)            (None, 128)          0           embedding_63[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 16)           0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16)           0           embedding_1[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 3)            0           time_input[0][0]
#                                                                  tf.math.sqrt[0][0]
#                                                                  tf.math.square[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4)            0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 2)            0           embedding_3[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 16)        1118048     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 16)        170832      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 16)           0           flatten_6[0][0]
#                                                                  flatten_7[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 32)           0           embedding_8[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 32)           0           embedding_9[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 8)            0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 4)            0           embedding_11[0][0]
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 1, 32)        2236096     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 1, 32)        341664      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 32)           0           flatten_15[0][0]
#                                                                  flatten_16[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 48)           0           embedding_16[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 48)           0           embedding_17[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 12)           0           global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 6)            0           embedding_19[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 1, 48)        3354144     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 1, 48)        512496      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 48)           0           flatten_24[0][0]
#                                                                  flatten_25[0][0]
# __________________________________________________________________________________________________
# flatten_27 (Flatten)            (None, 64)           0           embedding_24[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 64)           0           embedding_25[0][0]
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 16)           0           global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 8)            0           embedding_27[0][0]
# __________________________________________________________________________________________________
# embedding_28 (Embedding)        (None, 1, 64)        4472192     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_29 (Embedding)        (None, 1, 64)        683328      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 64)           0           flatten_33[0][0]
#                                                                  flatten_34[0][0]
# __________________________________________________________________________________________________
# flatten_36 (Flatten)            (None, 80)           0           embedding_32[0][0]
# __________________________________________________________________________________________________
# flatten_37 (Flatten)            (None, 80)           0           embedding_33[0][0]
# __________________________________________________________________________________________________
# flatten_38 (Flatten)            (None, 20)           0           global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_39 (Flatten)            (None, 10)           0           embedding_35[0][0]
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 1, 80)        5590240     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 1, 80)        854160      movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 80)           0           flatten_42[0][0]
#                                                                  flatten_43[0][0]
# __________________________________________________________________________________________________
# flatten_45 (Flatten)            (None, 96)           0           embedding_40[0][0]
# __________________________________________________________________________________________________
# flatten_46 (Flatten)            (None, 96)           0           embedding_41[0][0]
# __________________________________________________________________________________________________
# flatten_47 (Flatten)            (None, 24)           0           global_average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_48 (Flatten)            (None, 12)           0           embedding_43[0][0]
# __________________________________________________________________________________________________
# embedding_44 (Embedding)        (None, 1, 96)        6708288     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_45 (Embedding)        (None, 1, 96)        1024992     movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 96)           0           flatten_51[0][0]
#                                                                  flatten_52[0][0]
# __________________________________________________________________________________________________
# flatten_54 (Flatten)            (None, 112)          0           embedding_48[0][0]
# __________________________________________________________________________________________________
# flatten_55 (Flatten)            (None, 112)          0           embedding_49[0][0]
# __________________________________________________________________________________________________
# flatten_56 (Flatten)            (None, 28)           0           global_average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_57 (Flatten)            (None, 14)           0           embedding_51[0][0]
# __________________________________________________________________________________________________
# embedding_52 (Embedding)        (None, 1, 112)       7826336     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_53 (Embedding)        (None, 1, 112)       1195824     movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 112)          0           flatten_60[0][0]
#                                                                  flatten_61[0][0]
# __________________________________________________________________________________________________
# flatten_63 (Flatten)            (None, 128)          0           embedding_56[0][0]
# __________________________________________________________________________________________________
# flatten_64 (Flatten)            (None, 128)          0           embedding_57[0][0]
# __________________________________________________________________________________________________
# flatten_65 (Flatten)            (None, 32)           0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_66 (Flatten)            (None, 16)           0           embedding_59[0][0]
# __________________________________________________________________________________________________
# embedding_60 (Embedding)        (None, 1, 128)       8944384     user_input[0][0]
# __________________________________________________________________________________________________
# embedding_61 (Embedding)        (None, 1, 128)       1366656     movie_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 128)          0           flatten_69[0][0]
#                                                                  flatten_70[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 41)           0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 16)           0           embedding_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 16)           0           embedding_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None,)              0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 79)           0           flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 32)           0           embedding_12[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 32)           0           embedding_13[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None,)              0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.concat_5 (TFOpLambda)        (None, 117)          0           flatten_18[0][0]
#                                                                  flatten_19[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_20[0][0]
#                                                                  flatten_21[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 48)           0           embedding_20[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 48)           0           embedding_21[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_2 (TFOpLambd (None,)              0           tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.concat_7 (TFOpLambda)        (None, 155)          0           flatten_27[0][0]
#                                                                  flatten_28[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_29[0][0]
#                                                                  flatten_30[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 64)           0           embedding_28[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 64)           0           embedding_29[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_3 (TFOpLambd (None,)              0           tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.concat_9 (TFOpLambda)        (None, 193)          0           flatten_36[0][0]
#                                                                  flatten_37[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_38[0][0]
#                                                                  flatten_39[0][0]
# __________________________________________________________________________________________________
# flatten_40 (Flatten)            (None, 80)           0           embedding_36[0][0]
# __________________________________________________________________________________________________
# flatten_41 (Flatten)            (None, 80)           0           embedding_37[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_4 (TFOpLambd (None,)              0           tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# tf.concat_11 (TFOpLambda)       (None, 231)          0           flatten_45[0][0]
#                                                                  flatten_46[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_47[0][0]
#                                                                  flatten_48[0][0]
# __________________________________________________________________________________________________
# flatten_49 (Flatten)            (None, 96)           0           embedding_44[0][0]
# __________________________________________________________________________________________________
# flatten_50 (Flatten)            (None, 96)           0           embedding_45[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_5 (TFOpLambd (None,)              0           tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.concat_13 (TFOpLambda)       (None, 269)          0           flatten_54[0][0]
#                                                                  flatten_55[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_56[0][0]
#                                                                  flatten_57[0][0]
# __________________________________________________________________________________________________
# flatten_58 (Flatten)            (None, 112)          0           embedding_52[0][0]
# __________________________________________________________________________________________________
# flatten_59 (Flatten)            (None, 112)          0           embedding_53[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_6 (TFOpLambd (None,)              0           tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# tf.concat_15 (TFOpLambda)       (None, 307)          0           flatten_63[0][0]
#                                                                  flatten_64[0][0]
#                                                                  tf.concat[0][0]
#                                                                  flatten_65[0][0]
#                                                                  flatten_66[0][0]
# __________________________________________________________________________________________________
# flatten_67 (Flatten)            (None, 128)          0           embedding_60[0][0]
# __________________________________________________________________________________________________
# flatten_68 (Flatten)            (None, 128)          0           embedding_61[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_7 (TFOpLambd (None,)              0           tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            336         tf.concat_1[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1)            0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           1280        tf.concat_3[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           flatten_13[0][0]
#                                                                  flatten_14[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 1)            0           tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 24)           2832        tf.concat_5[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1)            0           flatten_22[0][0]
#                                                                  flatten_23[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 1)            0           tf.math.reduce_sum_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           4992        tf.concat_7[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 1)            0           flatten_31[0][0]
#                                                                  flatten_32[0][0]
# __________________________________________________________________________________________________
# flatten_35 (Flatten)            (None, 1)            0           tf.math.reduce_sum_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           7760        tf.concat_9[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1)            0           flatten_40[0][0]
#                                                                  flatten_41[0][0]
# __________________________________________________________________________________________________
# flatten_44 (Flatten)            (None, 1)            0           tf.math.reduce_sum_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 48)           11136       tf.concat_11[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1)            0           flatten_49[0][0]
#                                                                  flatten_50[0][0]
# __________________________________________________________________________________________________
# flatten_53 (Flatten)            (None, 1)            0           tf.math.reduce_sum_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 56)           15120       tf.concat_13[0][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 1)            0           flatten_58[0][0]
#                                                                  flatten_59[0][0]
# __________________________________________________________________________________________________
# flatten_62 (Flatten)            (None, 1)            0           tf.math.reduce_sum_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           19712       tf.concat_15[0][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 1)            0           flatten_67[0][0]
#                                                                  flatten_68[0][0]
# __________________________________________________________________________________________________
# flatten_71 (Flatten)            (None, 1)            0           tf.math.reduce_sum_7[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 10)           0           dense[0][0]
#                                                                  dot[0][0]
#                                                                  flatten_8[0][0]
# __________________________________________________________________________________________________
# tf.concat_4 (TFOpLambda)        (None, 18)           0           dense_1[0][0]
#                                                                  dot_1[0][0]
#                                                                  flatten_17[0][0]
# __________________________________________________________________________________________________
# tf.concat_6 (TFOpLambda)        (None, 26)           0           dense_2[0][0]
#                                                                  dot_2[0][0]
#                                                                  flatten_26[0][0]
# __________________________________________________________________________________________________
# tf.concat_8 (TFOpLambda)        (None, 34)           0           dense_3[0][0]
#                                                                  dot_3[0][0]
#                                                                  flatten_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_10 (TFOpLambda)       (None, 42)           0           dense_4[0][0]
#                                                                  dot_4[0][0]
#                                                                  flatten_44[0][0]
# __________________________________________________________________________________________________
# tf.concat_12 (TFOpLambda)       (None, 50)           0           dense_5[0][0]
#                                                                  dot_5[0][0]
#                                                                  flatten_53[0][0]
# __________________________________________________________________________________________________
# tf.concat_14 (TFOpLambda)       (None, 58)           0           dense_6[0][0]
#                                                                  dot_6[0][0]
#                                                                  flatten_62[0][0]
# __________________________________________________________________________________________________
# tf.concat_16 (TFOpLambda)       (None, 66)           0           dense_7[0][0]
#                                                                  dot_7[0][0]
#                                                                  flatten_71[0][0]
# __________________________________________________________________________________________________
# tf.concat_17 (TFOpLambda)       (None, 304)          0           tf.concat_2[0][0]
#                                                                  tf.concat_4[0][0]
#                                                                  tf.concat_6[0][0]
#                                                                  tf.concat_8[0][0]
#                                                                  tf.concat_10[0][0]
#                                                                  tf.concat_12[0][0]
#                                                                  tf.concat_14[0][0]
#                                                                  tf.concat_16[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            305         tf.concat_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 1)            0           dense_8[0][0]
# ==================================================================================================
# Total params: 139,291,817
# Trainable params: 139,291,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training
def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

model.compile(optimizer=tf.keras.optimizers.Adam(1e-3 / 2), loss='mse', metrics=[rmse])
batch_size = 4096*8
epochs = 128

callback = tf.keras.callbacks.EarlyStopping(monitor='val_rmse', patience=1, restore_best_weights=True)
history = model.fit([train.userId, train.movieId, train.timestamp, train.iloc[:,4:4+n_genres], train.day], train.rating,
                batch_size=batch_size, epochs=epochs, callbacks=[callback],
                validation_data = ([valid.userId, valid.movieId, valid.timestamp, valid.iloc[:,4:4+n_genres], valid.day], valid.rating), verbose = 1)
# Out:
# Epoch 1/128
# 275/275 [==============================] - 593s 2s/step - loss: 1.3127 - rmse: 0.9998 - val_loss: 0.8357 - val_rmse: 0.8621
# Epoch 2/128
# 275/275 [==============================] - 581s 2s/step - loss: 0.7957 - rmse: 0.8568 - val_loss: 0.7780 - val_rmse: 0.8573
# Epoch 3/128
# 275/275 [==============================] - 598s 2s/step - loss: 0.7380 - rmse: 0.8347 - val_loss: 0.7068 - val_rmse: 0.8147
# Epoch 4/128
# 275/275 [==============================] - 579s 2s/step - loss: 0.6229 - rmse: 0.7564 - val_loss: 0.6655 - val_rmse: 0.7801
# Epoch 5/128
# 275/275 [==============================] - 574s 2s/step - loss: 0.4806 - rmse: 0.6442 - val_loss: 0.6659 - val_rmse: 0.7702
# Epoch 6/128
# 275/275 [==============================] - 573s 2s/step - loss: 0.3541 - rmse: 0.5248 - val_loss: 0.6811 - val_rmse: 0.7731

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse', metrics=[rmse])
history = model.fit([train.userId, train.movieId, train.timestamp, train.iloc[:,4:4+n_genres], train.day], train.rating,
                batch_size=batch_size, epochs=epochs, callbacks=[callback],
                validation_data = ([valid.userId, valid.movieId, valid.timestamp, valid.iloc[:,4:4+n_genres], valid.day], valid.rating), verbose = 1)
# Out:
# Epoch 1/128
# 275/275 [==============================] - 593s 2s/step - loss: 0.3599 - rmse: 0.5355 - val_loss: 0.6649 - val_rmse: 0.7690
# Epoch 2/128
# 275/275 [==============================] - 587s 2s/step - loss: 0.3427 - rmse: 0.5183 - val_loss: 0.6656 - val_rmse: 0.7689
# Epoch 3/128
# 275/275 [==============================] - 582s 2s/step - loss: 0.3269 - rmse: 0.5020 - val_loss: 0.6670 - val_rmse: 0.7692

# %%
# check final RMSE
valid_pred = model.predict([valid.userId, valid.movieId, valid.timestamp, valid.iloc[:,4:4+n_genres], valid.day], batch_size = batch_size)
valid['pred'] = pd.DataFrame([float(x) for x in valid_pred], index=valid.index, columns=['pred'])
valid['pred'] = valid['pred'].apply(lambda x: max(min(x, 5), 0.5))

test_rmse = mean_squared_error(valid.rating, valid.pred, squared=False) # squared=False -> RMSE
print("test_rmse = " + str(test_rmse))
plt.hist(valid['pred'] - valid['rating'])
# Out:
# test_rmse = 0.7688419747537952
# (array([5.90000e+01, 1.18200e+03, 1.95200e+04, 1.75484e+05, 4.61584e+05,
#         2.61814e+05, 6.35900e+04, 1.41470e+04, 2.50000e+03, 1.26000e+02]),
#  array([-4.01278484, -3.16261643, -2.31244802, -1.46227962, -0.61211121,
#          0.2380572 ,  1.0882256 ,  1.93839401,  2.78856242,  3.63873082,
#          4.48889923]),
#  <a list of 10 Patch objects>)
